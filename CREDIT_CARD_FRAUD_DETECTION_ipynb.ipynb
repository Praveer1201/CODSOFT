# %% [markdown]
# <a href="https://colab.research.google.com/github/Praveer1201/CODSOFT/blob/main/CREDIT_CARD_FRAUD_DETECTION_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Importing the Dependencies**

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# loading the dataset to a Pandas DataFrame
credit_card_data = pd.read_csv('/content/fraudTest.csv (1).zip')

# %%
# first 5 rows of the dataset
credit_card_data.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2020-06-21 12:14:25  2291163933867244
# 1           1   2020-06-21 12:14:33  3573030041201292
# 2           2   2020-06-21 12:14:53  3598215285024754
# 3           3   2020-06-21 12:15:15  3591919803438423
# 4           4   2020-06-21 12:15:17  3526826139003047
#
#                                merchant        category    amt   first  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86    Jeff
# 1                  fraud_Sporer-Keebler   personal_care  29.84  Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28  Ashley
# 3                     fraud_Haley Group        misc_pos  60.05   Brian
# 4                 fraud_Johnston-Casper          travel   3.19  Nathan
#
#        last gender                       street  ...      lat      long  \
# 0   Elliott      M            351 Darlene Green  ...  33.9659  -80.9355
# ...

# %%
credit_card_data.tail()
# Out:
#         Unnamed: 0 trans_date_trans_time            cc_num  \
# 555714      555714   2020-12-31 23:59:07    30560609640617
# 555715      555715   2020-12-31 23:59:09  3556613125071656
# 555716      555716   2020-12-31 23:59:15  6011724471098086
# 555717      555717   2020-12-31 23:59:24     4079773899158
# 555718      555718   2020-12-31 23:59:34  4170689372027579
#
#                      merchant        category     amt    first     last  \
# 555714  fraud_Reilly and Sons  health_fitness   43.77  Michael    Olson
# 555715   fraud_Hoppe-Parisian       kids_pets  111.84     Jose  Vasquez
# 555716        fraud_Rau-Robel       kids_pets   86.88      Ann   Lawson
# 555717  fraud_Breitenberg LLC          travel    7.99     Eric  Preston
# 555718      fraud_Dare-Marvin   entertainment   38.13   Samuel     Frey
#
#        gender                      street  ...      lat      long  city_pop  \
# 555714      M         558 Michael Estates  ...  40.4931  -91.8912       519
# ...

# %%
credit_card_data_newdf = credit_card_data.drop("trans_date_trans_time", axis=1).drop('dob', axis=1)

print(credit_card_data_newdf)
# Out:
#         Unnamed: 0            cc_num                              merchant  \
# 0                0  2291163933867244                 fraud_Kirlin and Sons
# 1                1  3573030041201292                  fraud_Sporer-Keebler
# 2                2  3598215285024754  fraud_Swaniawski, Nitzsche and Welch
# 3                3  3591919803438423                     fraud_Haley Group
# 4                4  3526826139003047                 fraud_Johnston-Casper
# ...            ...               ...                                   ...
# 555714      555714    30560609640617                 fraud_Reilly and Sons
# 555715      555715  3556613125071656                  fraud_Hoppe-Parisian
# 555716      555716  6011724471098086                       fraud_Rau-Robel
# 555717      555717     4079773899158                 fraud_Breitenberg LLC
# 555718      555718  4170689372027579                     fraud_Dare-Marvin
#
#               category     amt    first      last gender  \
# ...

# %%
credit_card_data_newdf.head()
# Out:
#    Unnamed: 0            cc_num                              merchant  \
# 0           0  2291163933867244                 fraud_Kirlin and Sons
# 1           1  3573030041201292                  fraud_Sporer-Keebler
# 2           2  3598215285024754  fraud_Swaniawski, Nitzsche and Welch
# 3           3  3591919803438423                     fraud_Haley Group
# 4           4  3526826139003047                 fraud_Johnston-Casper
#
#          category    amt   first      last gender  \
# 0   personal_care   2.86    Jeff   Elliott      M
# 1   personal_care  29.84  Joanne  Williams      F
# 2  health_fitness  41.28  Ashley     Lopez      F
# 3        misc_pos  60.05   Brian  Williams      M
# 4          travel   3.19  Nathan    Massey      M
#
#                         street        city  ...    zip      lat      long  \
# 0            351 Darlene Green    Columbia  ...  29209  33.9659  -80.9355
# 1             3638 Marsh Union     Altonah  ...  84002  40.3207 -110.4360
# ...

# %%
# dataset informations
credit_card_data_newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555719 entries, 0 to 555718
# Data columns (total 21 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  555719 non-null  int64
#  1   cc_num      555719 non-null  int64
#  2   merchant    555719 non-null  object
#  3   category    555719 non-null  object
#  4   amt         555719 non-null  float64
#  5   first       555719 non-null  object
#  6   last        555719 non-null  object
#  7   gender      555719 non-null  object
#  8   street      555719 non-null  object
#  9   city        555719 non-null  object
#  10  state       555719 non-null  object
#  11  zip         555719 non-null  int64
#  12  lat         555719 non-null  float64
#  13  long        555719 non-null  float64
#  14  city_pop    555719 non-null  int64
#  15  job         555719 non-null  object
#  16  trans_num   555719 non-null  object
#  17  unix_time   555719 non-null  int64
# ...

# %%
# checking the number of missing values in each column
credit_card_data_newdf.isnull().sum()
# Out:
# Unnamed: 0    0
# cc_num        0
# merchant      0
# category      0
# amt           0
# first         0
# last          0
# gender        0
# street        0
# city          0
# state         0
# zip           0
# lat           0
# long          0
# city_pop      0
# job           0
# trans_num     0
# unix_time     0
# merch_lat     0
# merch_long    0
# is_fraud      0
# dtype: int64

# %%
# distribution of legit transactions & fraudulent transactions
credit_card_data_newdf['is_fraud'].value_counts()
# Out:
# 0    553574
# 1      2145
# Name: is_fraud, dtype: int64

# %% [markdown]
# **This Dataset is highly unblanced**

# %%
# separating the data for analysis
legit = credit_card_data_newdf[credit_card_data.is_fraud== 0]
fraud = credit_card_data_newdf[credit_card_data.is_fraud== 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (553574, 21)
# (2145, 21)

# %%
# statistical measures of the data
legit.amt.describe()
# Out:
# count    553574.000000
# mean         67.614408
# std         152.471931
# min           1.000000
# 25%           9.600000
# 50%          47.150000
# 75%          82.620000
# max       22768.110000
# Name: amt, dtype: float64

# %%
fraud.amt.describe()
# Out:
# count    2145.000000
# mean      528.356494
# std       392.747594
# min         1.780000
# 25%       214.510000
# 50%       371.940000
# 75%       907.770000
# max      1320.920000
# Name: amt, dtype: float64

# %%
# compare the values for both transactions
credit_card_data_newdf.groupby('is_fraud').mean()
# Out:
# <ipython-input-189-1baa13a1ec3c>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   credit_card_data_newdf.groupby('is_fraud').mean()
#              Unnamed: 0        cc_num         amt           zip        lat  \
# is_fraud
# 0         277997.725990  4.179643e+17   67.614408  48846.424285  38.541406
# 1         242057.088112  3.854274e+17  528.356494  47862.900233  39.019971
#
#                long      city_pop     unix_time  merch_lat  merch_long
# is_fraud
# 0        -90.230495  88313.692365  1.380683e+09  38.540954  -90.230474
# 1        -90.445556  64529.321678  1.379587e+09  39.018618  -90.465222

# %% [markdown]
# **under sampling**

# %%
legit_sample = legit.sample(n=492)

# %% [markdown]
# **Concatenating two DataFrames**

# %%
new_dataset = pd.concat([legit_sample, fraud], axis=0)

# %%
new_dataset.head()
# Out:
#         Unnamed: 0            cc_num                            merchant  \
# 420501      420501  4147608975828480                  fraud_Lynch-Wisozk
# 132868      132868  3595192916105588       fraud_Kuhic, Bins and Pfeffer
# 375982      375982  4904681492230012             fraud_Jaskolski-Dibbert
# 254667      254667  2706977570537524    fraud_Lehner, Reichert and Mills
# 495292      495292  2712209726293386  fraud_Crist, Jakubowski and Littel
#
#             category      amt   first     last gender  \
# 420501          home    12.50  Edward    Tapia      M
# 132868  shopping_net  1811.73  Dustin  Roberts      M
# 375982   grocery_net    52.79    Lisa     Lowe      F
# 254667      misc_pos    33.37   David  Serrano      M
# 495292          home    20.10   Jenna   Brooks      F
#
#                             street          city  ...    zip      lat  \
# 420501       354 Gutierrez Gateway       Comfrey  ...  56019  44.1111
# ...

# %%
new_dataset.tail()
# Out:
#         Unnamed: 0            cc_num                             merchant  \
# 517197      517197  2242176657877538      fraud_Willms, Kris and Bergnaum
# 517274      517274  2242176657877538                       fraud_Kuhn LLC
# 517341      517341  2242176657877538  fraud_Mosciski, Ziemann and Farrell
# 517529      517529  2242176657877538                   fraud_Bauch-Raynor
# 517571      517571  2242176657877538           fraud_Jaskolski-Vandervort
#
#             category      amt   first    last gender  \
# 517197  shopping_pos  1041.51  Travis  Daniel      M
# 517274  shopping_pos   868.09  Travis  Daniel      M
# 517341  shopping_net  1039.42  Travis  Daniel      M
# 517529   grocery_pos   289.27  Travis  Daniel      M
# 517571      misc_net   766.38  Travis  Daniel      M
#
#                              street       city  ...    zip      lat     long  \
# 517197  1327 Rose Causeway Apt. 610  Senatobia  ...  38668  34.6323 -89.8855
# ...

# %%
new_dataset['is_fraud'].value_counts()
# Out:
# 1    2145
# 0     492
# Name: is_fraud, dtype: int64

# %%
new_dataset.groupby('is_fraud').mean()
# Out:
# <ipython-input-195-0615df9acffe>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   new_dataset.groupby('is_fraud').mean()
#              Unnamed: 0        cc_num         amt           zip        lat  \
# is_fraud
# 0         272571.036585  4.314732e+17   67.965041  47755.567073  38.683777
# 1         242057.088112  3.854274e+17  528.356494  47862.900233  39.019971
#
#                long      city_pop     unix_time  merch_lat  merch_long
# is_fraud
# 0        -89.875377  96266.229675  1.380498e+09  38.662123  -89.872075
# 1        -90.445556  64529.321678  1.379587e+09  39.018618  -90.465222

# %% [markdown]
# **Splitting the data into Features & Targets**

# %%
X = new_dataset.drop(columns='is_fraud', axis=1)
Y = new_dataset['is_fraud']

# %%
print(X)
# Out:
#         Unnamed: 0            cc_num                             merchant  \
# 420501      420501  4147608975828480                   fraud_Lynch-Wisozk
# 132868      132868  3595192916105588        fraud_Kuhic, Bins and Pfeffer
# 375982      375982  4904681492230012              fraud_Jaskolski-Dibbert
# 254667      254667  2706977570537524     fraud_Lehner, Reichert and Mills
# 495292      495292  2712209726293386   fraud_Crist, Jakubowski and Littel
# ...            ...               ...                                  ...
# 517197      517197  2242176657877538      fraud_Willms, Kris and Bergnaum
# 517274      517274  2242176657877538                       fraud_Kuhn LLC
# 517341      517341  2242176657877538  fraud_Mosciski, Ziemann and Farrell
# 517529      517529  2242176657877538                   fraud_Bauch-Raynor
# 517571      517571  2242176657877538           fraud_Jaskolski-Vandervort
#
#             category      amt   first     last gender  \
# ...

# %%
print(Y)
# Out:
# 420501    0
# 132868    0
# 375982    0
# 254667    0
# 495292    0
#          ..
# 517197    1
# 517274    1
# 517341    1
# 517529    1
# 517571    1
# Name: is_fraud, Length: 2637, dtype: int64

# %% [markdown]
# #**model trainning**
#
# ***logistic regression***

# %%
model = LogisticRegression()

# %%
x_train = pd.read_csv('/content/fraudTest.csv (1).zip')
x_train = x_train.drop('trans_date_trans_time', axis=1).drop('dob', axis=1)

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# **Accuracy Score**

# %%
# accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on Training data : ', training_data_accuracy)

# %%
# accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy score on Test Data : ', test_data_accuracy)
